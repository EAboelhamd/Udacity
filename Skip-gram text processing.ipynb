# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# ## Unzip and read the text file ..

# %%
filename = 'text8.zip'
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# ## Reading the dictionary and replacing the unkown vocab with UNK:

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# ## Training batch generation:

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'anarchism', 'term', 'originated', 'term', 'of', 'as']

# %% [markdown]
# ## Train a skip gram model:

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                   train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %% [markdown]
# ## Run the model:
# by running the model we expect to have set of words from the dictionary and their best matches words, as well as the average similarity loss using L2 norm distance (which is not make sense and this is why we gonna try t-SNE)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
#     tf.global_variables_initializer().run()
    session.run(tf.initialize_all_variables())
    print('Initialized')
    average_loss = 0
    
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
# The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.490644
# Nearest to most: unfilled, hus, symbolism, oppressors, ebenezer, handedly, bordeaux, unsolvable,
# Nearest to it: turf, varuna, boltzmann, inti, carp, lollardy, idf, sichuan,
# Nearest to only: strived, eurasia, thorn, tanto, weighing, hetfield, logos, canonization,
# Nearest to s: realisation, scarcity, sherlock, schizophrenia, adams, unita, flagging, qua,
# Nearest to at: musicologist, melcher, papert, immediate, flatter, hereby, fours, flywheels,
# Nearest to their: banks, guitarists, racecar, fairer, darts, befitting, promises, diseased,
# Nearest to from: gloucestershire, folkloric, yury, sitcoms, indictments, restrict, maha, cleves,
# Nearest to time: galley, trampled, radiocarbon, acre, threats, privates, blotting, transporter,
# Nearest to a: peasant, oxidize, fresnel, kalmar, hitchhikers, reported, reticent, pedagogic,
# Nearest to were: jurgen, antlers, articles, seemed, stampede, personally, rampage, addressee,
# Nearest to so: plugging, orator, utica, feared, bz, airfoil, articulated, cravings,
# Nearest to which: poured, neuropathy, murr, herbs, validate, firms, heathrow, dativus,
# Nearest to states: parabolic, plaid, phagocytosis, usual, kzin, sampling, mappings, followed,
# Nearest to world: crank, elie, decompose, plunges, recognises, taif, performances, hundred,
# Nearest to th: dmitry, livia, ghul, xiongnu, behistun, islamism, edwina, hispano,
# Nearest to also: oval, leben, formulaic, whence, balboa, vitally, allotted, logistics,
# Average loss at step 2000: 4.376559
# Average loss at step 4000: 3.870883
# Average loss at step 6000: 3.793784
# Average loss at step 8000: 3.750135
# Average loss at step 10000: 3.621658
# Nearest to most: esque, symbolism, posters, stampede, displays, occupational, incompleteness, secaucus,
# Nearest to it: he, this, there, which, nutty, antitrust, also, hexokinase,
# Nearest to only: strived, dyer, attest, steamed, altruism, hyperplasia, verso, tropic,
# Nearest to s: or, and, the, racetrack, isbn, rosalyn, wherein, nephew,
# Nearest to at: in, inherited, os, from, on, warcraft, primrose, ancestors,
# Nearest to their: its, his, the, befitting, emulated, hans, charlatans, theropod,
# Nearest to from: in, on, and, by, bacall, at, with, gloucestershire,
# Nearest to time: privates, flopped, acre, underpinning, trampled, mutations, galley, boycott,
# Nearest to a: the, indus, preamble, donuts, glory, their, optically, constructors,
# Nearest to were: are, was, have, is, has, by, had, protestant,
# Nearest to so: feared, plugging, scalia, airfoil, orator, pioneer, boston, intuitionistic,
# Nearest to which: that, this, it, newman, also, qh, there, imitating,
# Nearest to states: plaid, parabolic, usual, pointed, alcatraz, shiraz, followed, tabari,
# Nearest to world: hundred, crank, haul, plunges, performances, case, decompose, recognises,
# Nearest to th: five, dmitry, six, one, liquidity, livia, behistun, nicely,
# Nearest to also: who, leben, logistics, which, often, not, it, mate,
# Average loss at step 12000: 3.578918
# Average loss at step 14000: 3.611775
# Average loss at step 16000: 3.581176
# Average loss at step 18000: 3.569907
# Average loss at step 20000: 3.548464
# Nearest to most: more, many, some, strongest, stampede, nast, occupational, writers,
# Nearest to it: he, this, there, she, they, antitrust, which, we,
# Nearest to only: dyer, strived, attest, longitudinal, nation, beac, necessarily, hetfield,
# Nearest to s: isbn, and, his, riddle, motorbikes, lep, racetrack, anakin,
# Nearest to at: in, appel, on, after, from, following, mesoamerican, demobilization,
# Nearest to their: its, his, her, the, obedience, befitting, christianization, these,
# Nearest to from: by, in, into, bacall, at, cowes, conveniently, peptides,
# Nearest to time: underpinning, year, flopped, privates, polskiej, yak, acre, boycott,
# Nearest to a: the, any, no, vicars, hsieh, apostasy, his, ibm,
# Nearest to were: are, was, have, had, fries, be, ddrmax, by,
# Nearest to so: scalia, feared, plugging, hanna, pioneer, forfeited, flagship, intuitionistic,
# Nearest to which: that, also, this, it, who, llamas, demo, primitivism,
# Nearest to states: plaid, parabolic, pointed, racing, injurious, confronted, voiced, shiraz,
# Nearest to world: crank, haul, hundred, job, hypothermia, remotely, option, decompose,
# Nearest to th: dmitry, liquidity, livia, six, gadolinium, behistun, vre, accountable,
# Nearest to also: which, often, who, now, not, it, usually, pearlman,
# Average loss at step 22000: 3.524233
# Average loss at step 24000: 3.438225
# Average loss at step 26000: 3.418098
# Average loss at step 28000: 3.475937
# Average loss at step 30000: 3.409040
# Nearest to most: more, many, some, displays, boerhaave, nast, stampede, consultation,
# Nearest to it: he, there, this, she, which, they, antitrust, not,
# Nearest to only: attest, necessarily, dyer, strived, lavoisier, tilde, nation, byng,
# Nearest to s: caricatures, and, dodo, gard, contradicted, luoyang, retire, was,
# Nearest to at: in, on, demobilization, after, hangovers, under, appel, from,
# Nearest to their: his, its, her, the, obedience, totally, these, befitting,
# Nearest to from: into, in, bacall, between, conveniently, within, through, at,
# Nearest to time: period, polskiej, year, millie, underpinning, flopped, privates, existed,
# Nearest to a: the, arden, this, each, edgerton, vicars, preamble, ohlin,
# Nearest to were: are, was, have, had, is, ddrmax, be, neopagans,
# Nearest to so: scalia, flagship, plugging, dracula, feared, hanna, amps, pioneer,
# Nearest to which: this, that, also, there, who, it, thereupon, asphyxia,
# Nearest to states: plaid, racing, parabolic, voiced, injurious, mhz, pointed, thaw,
# Nearest to world: hundred, hypothermia, haul, militiamen, disagreement, remotely, rourke, option,
# Nearest to th: dmitry, one, gadolinium, theater, livia, vre, liquidity, hippie,
# Nearest to also: often, which, now, who, usually, still, winged, below,
# Average loss at step 32000: 3.417199
# Average loss at step 34000: 3.437360
# Average loss at step 36000: 3.367580
# Average loss at step 38000: 3.489098
# Average loss at step 40000: 3.441674
# Nearest to most: more, many, some, boerhaave, strongest, nast, occupational, enhancements,
# Nearest to it: he, there, she, they, this, we, which, not,
# Nearest to only: tilde, necessarily, usually, strived, dyer, currently, typically, followings,
# Nearest to s: his, isbn, whose, was, cleef, caesura, luoyang, lugosi,
# Nearest to at: on, in, from, demobilization, hangovers, after, under, appel,
# Nearest to their: its, his, her, the, obedience, these, our, both,
# Nearest to from: into, bacall, at, within, for, in, boc, on,
# Nearest to time: period, year, polskiej, flopped, existed, glyph, hillbillies, outright,
# Nearest to a: any, the, no, another, cree, seizes, motherland, skiing,
# Nearest to were: are, was, have, had, those, be, ddrmax, been,
# Nearest to so: how, thus, scalia, flagship, lad, hanna, induction, strategist,
# Nearest to which: that, this, who, but, also, there, these, it,
# Nearest to states: nations, racing, injurious, plaid, hazlitt, pointed, subplot, polski,
# Nearest to world: hypothermia, haul, hundred, largest, militiamen, crank, remotely, disagreement,
# Nearest to th: dmitry, gadolinium, ninth, hippie, livia, aristophanes, vre, stalactites,
# Nearest to also: often, which, now, winged, usually, pearlman, sometimes, marcelo,
# Average loss at step 42000: 3.426947
# Average loss at step 44000: 3.274794
# Average loss at step 46000: 3.408774
# Average loss at step 48000: 3.432554
# Average loss at step 50000: 3.433390
# Nearest to most: more, many, some, strongest, boerhaave, among, nast, occupational,
# Nearest to it: he, there, she, this, they, we, spares, gnawing,
# Nearest to only: currently, strived, tilde, timelines, usually, typically, gpl, actually,
# Nearest to s: his, cleef, and, schizophrenia, luoyang, whose, isbn, televisions,
# Nearest to at: in, under, demobilization, tailed, on, after, near, during,
# Nearest to their: its, his, her, the, our, obedience, these, befitting,
# Nearest to from: into, in, bacall, bouvet, through, cowes, boc, within,
# Nearest to time: period, polskiej, year, flopped, glyph, gonzalo, name, outright,
# Nearest to a: the, another, any, no, atalanta, edgerton, lcms, stereo,
# Nearest to were: are, was, have, had, those, been, by, is,
# Nearest to so: how, thus, induction, supplanted, limitless, saying, seaborg, too,
# Nearest to which: this, that, who, what, there, also, it, these,
# Nearest to states: nations, kingdom, hazlitt, us, injurious, subplot, state, racing,
# Nearest to world: haul, gulf, crank, rhine, bloc, pediment, pinball, obligate,
# Nearest to th: one, five, livia, hippie, dmitry, ninth, six, ad,
# Nearest to also: often, now, which, pearlman, still, usually, moretti, winged,
# Average loss at step 52000: 3.457947
# Average loss at step 54000: 3.429638
# Average loss at step 56000: 3.405229
# Average loss at step 58000: 3.276538
# Average loss at step 60000: 3.383855
# Nearest to most: more, many, some, among, strongest, stampede, boerhaave, less,
# Nearest to it: he, there, she, this, which, they, cruises, spares,
# Nearest to only: usually, typically, actually, currently, gpl, still, necessarily, tilde,
# Nearest to s: whose, isbn, caricatures, ecologist, his, and, caesura, waldeck,
# Nearest to at: in, during, hangovers, under, tailed, demobilization, throughout, after,
# Nearest to their: its, his, her, our, the, these, obedience, ilium,
# Nearest to from: into, through, in, bacall, within, by, under, cowes,
# Nearest to time: period, year, issue, way, existed, polskiej, glyph, days,
# Nearest to a: the, another, any, roussimoff, fibs, karaca, brood, sabrina,
# Nearest to were: are, was, have, those, been, hmac, being, be,
# Nearest to so: thus, how, too, scalia, felt, seaborg, if, lad,
# Nearest to which: that, this, who, also, what, it, there, these,
# Nearest to states: nations, kingdom, countries, injurious, us, hazlitt, confronted, kkinen,
# Nearest to world: militiamen, haul, rigid, remotely, hypothermia, rhine, gulf, crank,
# Nearest to th: one, four, six, ad, five, st, ninth, two,
# Nearest to also: often, which, now, still, usually, never, who, generally,
# Average loss at step 62000: 3.444557
# Average loss at step 64000: 3.355839
# Average loss at step 66000: 3.344268
# Average loss at step 68000: 3.383881
# Average loss at step 70000: 3.371807
# Nearest to most: more, many, some, among, especially, less, boerhaave, strongest,
# Nearest to it: he, there, she, this, they, cruises, still, which,
# Nearest to only: tilde, usually, strived, either, currently, gpl, necessarily, typically,
# Nearest to s: whose, luoyang, his, dunne, waldeck, oghuz, ambients, planner,
# Nearest to at: in, on, during, throughout, tailed, around, chiang, fours,
# Nearest to their: its, his, her, the, our, whose, obedience, these,
# Nearest to from: through, into, in, cowes, boc, during, between, across,
# Nearest to time: period, year, issue, lapland, days, privates, gonzalo, way,
# Nearest to a: another, any, no, apostasy, semiconducting, roussimoff, the, atalanta,
# Nearest to were: are, have, those, had, been, was, hmac, ddrmax,
# Nearest to so: if, felt, too, livecd, how, sometimes, adamson, lad,
# Nearest to which: that, this, also, who, what, still, hazardous, imitating,
# Nearest to states: nations, kingdom, us, injurious, countries, subplot, state, hazlitt,
# Nearest to world: haul, gulf, militiamen, remotely, crank, rigid, rhine, bloc,
# Nearest to th: five, six, seven, eight, one, four, ad, hippie,
# Nearest to also: now, often, still, which, usually, winged, sometimes, never,
# Average loss at step 72000: 3.401390
# Average loss at step 74000: 3.392284
# Average loss at step 76000: 3.345470
# Average loss at step 78000: 3.235945
# Average loss at step 80000: 3.373386
# Nearest to most: more, many, some, among, especially, use, johnstone, less,
# Nearest to it: he, there, she, this, they, cruises, possible, which,
# Nearest to only: usually, normally, either, necessarily, gpl, still, all, any,
# Nearest to s: whose, his, luoyang, isbn, duplications, dave, corporeal, its,
# Nearest to at: in, during, throughout, tailed, after, christi, from, stosunku,
# Nearest to their: its, his, her, our, the, your, these, whose,
# Nearest to from: through, into, cowes, across, between, boc, dab, in,
# Nearest to time: period, year, lapland, gonzalo, deakin, polskiej, privates, glyph,
# Nearest to a: another, any, the, every, preamble, tha, arden, vicars,
# Nearest to were: are, was, have, although, hmac, those, had, including,
# Nearest to so: sometimes, thus, felt, too, if, lad, seaborg, vdash,
# Nearest to which: this, that, also, what, imitating, however, still, but,
# Nearest to states: nations, countries, kingdom, us, injurious, hazlitt, digamma, subplot,
# Nearest to world: gulf, militiamen, remotely, crank, haul, bloc, rigid, confectionery,
# Nearest to th: ad, hippie, six, flores, damnation, bce, ninth, stalactites,
# Nearest to also: often, still, which, now, usually, sometimes, always, currently,
# Average loss at step 82000: 3.296548
# Average loss at step 84000: 3.342804
# Average loss at step 86000: 3.343339
# Average loss at step 88000: 3.317646
# Average loss at step 90000: 3.237238
# Nearest to most: many, more, some, especially, less, occupational, uzbek, among,
# Nearest to it: he, she, there, this, they, still, often, cruises,
# Nearest to only: usually, last, until, probably, just, normally, ditches, necessarily,
# Nearest to s: whose, his, and, luoyang, platz, caricatures, skier, her,
# Nearest to at: in, during, after, around, chiang, sudden, near, demobilization,
# Nearest to their: its, her, his, our, my, these, your, whose,
# Nearest to from: through, boc, into, cowes, between, in, towards, by,
# Nearest to time: period, way, lapland, year, month, glyph, position, issue,
# Nearest to a: another, the, roussimoff, parnell, mussolini, rower, skillfully, karaca,
# Nearest to were: are, was, had, being, have, these, be, those,
# Nearest to so: thus, if, too, seaborg, felt, supplanted, very, livecd,
# Nearest to which: that, this, what, also, who, often, usually, imitating,
# Nearest to states: nations, kingdom, countries, us, state, subplot, hazlitt, polski,
# Nearest to world: gulf, crank, militiamen, remotely, confectionery, haul, bloc, petrified,
# Nearest to th: one, ad, hippie, ninth, bce, flores, vre, two,
# Nearest to also: often, which, now, still, never, usually, sometimes, eventually,
# Average loss at step 92000: 2.731654
# Average loss at step 94000: 3.104761
# Average loss at step 96000: 3.068182
# Average loss at step 98000: 3.219725
# Average loss at step 100000: 3.279668
# Nearest to most: more, many, some, less, among, especially, strongest, particularly,
# Nearest to it: he, she, there, this, still, they, now, cruises,
# Nearest to only: usually, either, probably, last, actually, currently, necessarily, until,
# Nearest to s: whose, his, isbn, biochemists, luoyang, abandonware, oghuz, caricatures,
# Nearest to at: during, around, huston, near, stosunku, demobilization, on, after,
# Nearest to their: its, his, her, our, these, your, the, whose,
# Nearest to from: through, boc, cowes, maluku, peptides, funerary, into, under,
# Nearest to time: period, year, issue, month, combating, glyph, days, vienna,
# Nearest to a: the, another, any, this, teamed, princeps, stews, zquez,
# Nearest to were: are, have, those, include, was, be, these, eradication,
# Nearest to so: thus, too, sometimes, very, felt, then, seaborg, harmonies,
# Nearest to which: that, this, what, also, but, imitating, who, primitivism,
# Nearest to states: nations, kingdom, us, countries, state, injurious, overseas, polski,
# Nearest to world: gulf, remotely, crank, year, ambulance, confectionery, militiamen, bloc,
# Nearest to th: hippie, flores, ad, nd, vre, st, third, bce,
# Nearest to also: often, now, still, usually, never, sometimes, which, actually,

# %% [markdown]
# ## T-SNE method:
# This method measures the distance between the words in your dictionary.
# let's try it with some plots to visualize the results

# %%
num_points = 400 ## selected words

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ## Comment:
# it seems the model obtains good results as demonestrated in the graph as probably the 400 words are near each other.

# %% [markdown]
# ## Let's try Continuous Bag-of-Words Model (CBOW):
# An alternative to skip-gram is another Word2Vec model called CBOW (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context.
